# %%
CATALOG = "Final_Project"

BRONZE_SCHEMA = "Bronze_Zone"
SILVER_SCHEMA = "Silver_Zone"
GOLD_SCHEMA   = "Gold_Zone"

META_SCHEMA = "pipeline_metadata"

RAW_VOLUME = "vol_raw_files"
STG_VOLUME = "vol_stg_files"

PARENT_META_TABLE = "parent_metadata"
CHILED_META_TABLE = "child_metadata"

BRONZE_DALLAS_TABLE  = "bronze_dallas"
BRONZE_CHICAGO_TABLE = "bronze_chicago"
SILVER_TABLE         = "silver_table"

DIM_DATE             = "dim_date"
DIM_RESTAURANT       = "dim_restaurant"
DIM_VIOLATION_DETAIL = "dim_violation_detail"
FACT_VIOLATIONS      = "fact_violations"
FACT_INSPECTIONS     = "fact_inspections"

GOLD_QUARANTINE_INSPECTION  = "Quarantine_Inspection"
GOLD_QUARANTINE_VIOLATION   = "Quarantine_Violation"


CHICAGO_FILE_NAME = "Chicago_Restaurant_and_Food_Establishment_Inspections.csv"
DALLAS_FILE_NAME  = "Dallas_Restaurant_and_Food_Establishment_Inspections.csv"

VOLUME_PATH = f"/Volumes/{CATALOG}/{BRONZE_SCHEMA}"
RAW_VOLUME_PATH = f"{VOLUME_PATH}/{RAW_VOLUME}"
STAGING_VOLUME_PATH = f"{VOLUME_PATH}/{STG_VOLUME}"

RAW_CHICAGO_PATH = f"{RAW_VOLUME_PATH}/{CHICAGO_FILE_NAME}"
RAW_DALLAS_PATH  = f"{RAW_VOLUME_PATH}/{DALLAS_FILE_NAME}"


LANDING_FILE_MAP = {
    "Chicago": RAW_CHICAGO_PATH,
    "Dallas": RAW_DALLAS_PATH
}

BRONZE_TABLE_MAP = {
    "Chicago": BRONZE_CHICAGO_TABLE,
    "Dallas" : BRONZE_DALLAS_TABLE
}

FILE_NAME_MAP = {
    "Chicago": "Chicago_Restaurant_and_Food_Establishment_Inspections",
    "Dallas": "Dallas_Restaurant_and_Food_Establishment_Inspections"
}
